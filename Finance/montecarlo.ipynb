# %%
import pandas as pd 
import numpy as np
from statsmodels.distributions.empirical_distribution import ECDF

# %%
sim = pd.DataFrame(np.random.normal(0, 0.1, [1000, 100])).T
sim
# Out:
#          0         1         2         3         4         5         6    \
# 0  -0.043974 -0.021512 -0.068343 -0.100872  0.150429  0.039064  0.080544
# 1   0.057676 -0.022879  0.100607  0.076083  0.093766 -0.016664 -0.131037
# 2  -0.009734  0.031822 -0.086521  0.096284  0.128776  0.002747  0.203199
# 3   0.227097  0.048280  0.019462 -0.016020  0.063887 -0.115641  0.102100
# 4  -0.057377  0.105658 -0.083701 -0.049923 -0.043418 -0.100140  0.201191
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.047648  0.086897  0.007834  0.013815 -0.028359  0.005405 -0.006955
# 96 -0.179713  0.136302 -0.088003 -0.094937 -0.009713  0.104536  0.119746
# 97 -0.070461  0.045306 -0.005407  0.218122 -0.127472  0.035462  0.157713
# 98  0.009735 -0.062564 -0.076818 -0.093247  0.054164 -0.088809  0.044991
# 99  0.039429  0.057558 -0.022702  0.155471  0.054359 -0.116888  0.144039
#
#          7         8         9    ...       990       991       992       993  \
# ...

# %%
rebased_sim = (sim + 1).cumprod() / ((sim + 1).iloc[0, :])

# %%
import seaborn as sns

sns.distplot(rebased_sim.iloc[-1, :], hist = False, kde = True,
                 kde_kws = {'linewidth': 2},
                 label = 'a')
plt.show()
